# %%
import PyMKF
import json
import pprint
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # List of the available core shapes from database
# we will do some analysis on the core shapes from the database
# - [x] histogram distribution of the core shapes from the market
# - [] correlation between the core shapes and the price
# - [] correlation between the core shapes and the weight
# - [] correlation between the core shapes and the volume
# - [] correlation between the core shapes and AL [nH/T**2]
# - [] correlation between the core shapes and area product Ap=Aw*Ac [mm**4]
# - [] correlation between the core shapes and Kg constant [mm**5]
# - [] correlation between the core shapes and surface area [mm**2] that is related to the heat transfer

# %% [markdown]
# ## Histogram distribution of the core shapes from the market
# Visible is that most common are the toroid, E, EQ, RM

# %%
l_materials = PyMKF.get_core_shapes()
print("Nr. of cores available: " + str(len(l_materials)))

# l_cores is a list of dictionaries, each dictionary contains the following keys:
all_keys = l_materials[0].keys()
df_cores = pd.DataFrame(columns=all_keys)

for idx, item in enumerate(l_materials):
    df_row = pd.DataFrame([item])
    df_cores = pd.concat([df_cores, df_row], ignore_index=True)

df_cores = df_cores.set_index('name')
df_cores.head(10)
# Out:
# Nr. of cores available: 1193
#                          aliases  \
# name
# E 10/5.5/5            [E 10.2/5]
# E 10/3                        []
# E 10/5.5/5            [E 10.2/5]
# E 100/60/21                   []
# E 100/60/28                   []
# E 102/20/38      [ELP 102/20/38]
# E 114/46/17.5                 []
# E 114/46/26                   []
# E 114/46/35                   []
# E 12.7/5.6/3.17               []
#
#                                                         dimensions    family  \
# name
# E 10/5.5/5       {'A': {'excludeMaximum': None, 'excludeMinimum...         e
# E 10/3           {'A': {'excludeMaximum': None, 'excludeMinimum...         e
# E 10/5.5/5       {'A': {'excludeMaximum': None, 'excludeMinimum...         e
# E 100/60/21      {'A': {'excludeMaximum': None, 'excludeMinimum...         e
# E 100/60/28      {'A': {'excludeMaximum': None, 'excludeMinimum...         e
# E 102/20/38      {'A': {'excludeMaximum': None, 'excludeMinimum...  planar e
# E 114/46/17.5    {'A': {'excludeMaximum': None, 'excludeMinimum...         e
# E 114/46/26      {'A': {'excludeMaximum': None, 'excludeMinimum...         e
# E 114/46/35      {'A': {'excludeMaximum': None, 'excludeMinimum...         e
# E 12.7/5.6/3.17  {'A': {'excludeMaximum': None, 'excludeMinimum...         e
#
#                 familySubtype magneticCircuit      type
# name
# E 10/5.5/5               None            open  standard
# E 10/3                   None            open  standard
# E 10/5.5/5               None            open  standard
# E 100/60/21              None            open  standard
# E 100/60/28              None            open  standard
# E 102/20/38              None            open  standard
# E 114/46/17.5            None            open  standard
# E 114/46/26              None            open  standard
# E 114/46/35              None            open  standard
# E 12.7/5.6/3.17          None            open  standard

# %%
# plot the cores histogram based on family column values in df_cores
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(df_cores['family'].value_counts().index, df_cores['family'].value_counts().values)
ax.set_xlabel('Core Family')
ax.set_ylabel('Number of Cores')
ax.set_title('Histogram of Core Families')
ax.xaxis.set_tick_params(rotation=45)
ax.grid(True)
plt.show()

# %% [markdown]
# ## correlation between the core shapes and the price
# currently not possible as the data is not available or correlated to manufacturers.

# %% [markdown]
# ## correlation between the core shapes and the weight

# %% [markdown]
# ## correlation between the core shapes and the aspect ratio

# %%
df_cores.iloc[0]['dimensions']
# Out:
# {'A': {'excludeMaximum': None,
#   'excludeMinimum': None,
#   'maximum': 0.0105,
#   'minimum': 0.01,
#   'nominal': None},
#  'B': {'excludeMaximum': None,
#   'excludeMinimum': None,
#   'maximum': 0.00565,
#   'minimum': 0.00535,
#   'nominal': None},
#  'C': {'excludeMaximum': None,
#   'excludeMinimum': None,
#   'maximum': 0.0049,
#   'minimum': 0.0045,
#   'nominal': None},
#  'D': {'excludeMaximum': None,
#   'excludeMinimum': None,
#   'maximum': 0.00435,
#   'minimum': 0.00405,
#   'nominal': None},
#  'E': {'excludeMaximum': None,
#   'excludeMinimum': None,
#   'maximum': 0.008,
#   'minimum': 0.0076,
#   'nominal': None},
#  'F': {'excludeMaximum': None,
#   'excludeMinimum': None,
#   'maximum': 0.0026,
#   'minimum': 0.0022,
#   'nominal': None}}

# %% [markdown]
# ## correlation between the core shapes and the volume

# %% [markdown]
# ## correlation between the core shapes and AL [nH/T**2]
# ## correlation between the core shapes and area product Ap=Aw*Ac [mm**4]
# ## correlation between the core shapes and Kg constant [mm**5]
# ## correlation between the core shapes and surface area [mm**2] that is related to the heat transfer

# %% [markdown]
# # Material properties section

# %%
# Material properties
l_materials = PyMKF.get_core_materials()
l_materials[0].keys()
# Out:
# dict_keys(['bhCycle', 'coerciveForce', 'curieTemperature', 'density', 'family', 'heatCapacity', 'heatConductivity', 'manufacturerInfo', 'material', 'materialComposition', 'name', 'permeability', 'remanence', 'resistivity', 'saturation', 'type', 'volumetricLosses'])

# %%
print("Nr. of cores available: " + str(len(l_materials)))

# l_cores is a list of dictionaries, each dictionary contains the following keys:
all_keys = l_materials[0].keys()
df_materials = pd.DataFrame(columns=all_keys)

for idx, item in enumerate(l_materials):
    df_row = pd.DataFrame([item])
    df_materials = pd.concat([df_materials, df_row], ignore_index=True)

df_materials = df_materials.set_index('name')
df_materials.head(10)
# Out:
# Nr. of cores available: 215
# /tmp/ipykernel_7521/1710614694.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_materials = pd.concat([df_materials, df_row], ignore_index=True)
#       bhCycle                                      coerciveForce  \
# name
# 3C90     None  [{'magneticField': 14.0, 'magneticFluxDensity'...
# 3C91     None  [{'magneticField': 10.0, 'magneticFluxDensity'...
# 3C92     None  [{'magneticField': 9.0, 'magneticFluxDensity':...
# 3C92A    None  [{'magneticField': 9.0, 'magneticFluxDensity':...
# 3C94     None  [{'magneticField': 14.0, 'magneticFluxDensity'...
# 3C95     None  [{'magneticField': 9.0, 'magneticFluxDensity':...
# 3C95A    None  [{'magneticField': 9.0, 'magneticFluxDensity':...
# 3C95F    None  [{'magneticField': 9.0, 'magneticFluxDensity':...
# 3C96     None  [{'magneticField': 10.0, 'magneticFluxDensity'...
# 3C97     None  [{'magneticField': 8.0, 'magneticFluxDensity':...
#
#        curieTemperature  density family  \
# name
# 3C90              220.0   4800.0     3C
# 3C91              220.0   4800.0     3C
# 3C92              270.0   4800.0     3C
# 3C92A             270.0   4900.0     3C
# 3C94              220.0   4800.0     3C
# 3C95              215.0   4800.0     3C
# 3C95A             220.0   4850.0     3C
# 3C95F             210.0   4850.0     3C
# 3C96              240.0   4800.0     3C
# 3C97              215.0   4800.0     3C
#
#                                             heatCapacity  \
# name
# 3C90   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C91   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C92   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C92A  {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C94   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C95   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C95A  {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C95F  {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C96   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C97   {'excludeMaximum': None, 'excludeMinimum': Non...
#
#                                         heatConductivity  \
# name
# 3C90   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C91   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C92   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C92A  {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C94   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C95   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C95A  {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C95F  {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C96   {'excludeMaximum': None, 'excludeMinimum': Non...
# 3C97   {'excludeMaximum': None, 'excludeMinimum': Non...
#
#                                         manufacturerInfo material  \
# name
# 3C90   {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
# 3C91   {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
# 3C92   {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
# 3C92A  {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
# 3C94   {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
# 3C95   {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
# 3C95A  {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
# 3C95F  {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
# 3C96   {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
# 3C97   {'cost': None, 'datasheetUrl': 'https://www.fe...  ferrite
#
#       materialComposition                                       permeability  \
# name
# 3C90                 None  {'amplitude': None, 'complex': None, 'initial'...
# 3C91                 None  {'amplitude': None, 'complex': None, 'initial'...
# 3C92                 None  {'amplitude': None, 'complex': None, 'initial'...
# 3C92A                None  {'amplitude': None, 'complex': None, 'initial'...
# 3C94                 None  {'amplitude': None, 'complex': None, 'initial'...
# 3C95                 None  {'amplitude': None, 'complex': None, 'initial'...
# 3C95A                None  {'amplitude': None, 'complex': None, 'initial'...
# 3C95F                None  {'amplitude': None, 'complex': None, 'initial'...
# 3C96                 None  {'amplitude': None, 'complex': None, 'initial'...
# 3C97                 None  {'amplitude': None, 'complex': None, 'initial'...
#
#                                                remanence  \
# name
# 3C90   [{'magneticField': 0.0, 'magneticFluxDensity':...
# 3C91   [{'magneticField': 0.0, 'magneticFluxDensity':...
# 3C92   [{'magneticField': 0.0, 'magneticFluxDensity':...
# 3C92A  [{'magneticField': 0.0, 'magneticFluxDensity':...
# 3C94   [{'magneticField': 0.0, 'magneticFluxDensity':...
# 3C95   [{'magneticField': 0.0, 'magneticFluxDensity':...
# 3C95A  [{'magneticField': 0.0, 'magneticFluxDensity':...
# 3C95F  [{'magneticField': 0.0, 'magneticFluxDensity':...
# 3C96   [{'magneticField': 0.0, 'magneticFluxDensity':...
# 3C97   [{'magneticField': 0.0, 'magneticFluxDensity':...
#
#                                              resistivity  \
# name
# 3C90               [{'temperature': 25.0, 'value': 5.0}]
# 3C91               [{'temperature': 25.0, 'value': 5.0}]
# 3C92               [{'temperature': 25.0, 'value': 5.0}]
# 3C92A              [{'temperature': 25.0, 'value': 5.0}]
# 3C94   [{'temperature': -20.0, 'value': 10.0}, {'temp...
# 3C95               [{'temperature': 25.0, 'value': 5.0}]
# 3C95A             [{'temperature': 25.0, 'value': 10.0}]
# 3C95F             [{'temperature': 25.0, 'value': 10.0}]
# 3C96               [{'temperature': 25.0, 'value': 5.0}]
# 3C97               [{'temperature': 25.0, 'value': 5.0}]
#
#                                               saturation        type  \
# name
# 3C90   [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
# 3C91   [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
# 3C92   [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
# 3C92A  [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
# 3C94   [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
# 3C95   [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
# 3C95A  [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
# 3C95F  [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
# 3C96   [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
# 3C97   [{'magneticField': 1200.0, 'magneticFluxDensit...  commercial
#
#                                         volumetricLosses
# name
# 3C90   {'default': [{'a': None, 'b': None, 'c': None,...
# 3C91   {'default': [{'a': None, 'b': None, 'c': None,...
# 3C92   {'default': [{'a': None, 'b': None, 'c': None,...
# 3C92A  {'default': [{'a': None, 'b': None, 'c': None,...
# 3C94   {'default': [{'a': None, 'b': None, 'c': None,...
# 3C95   {'default': [{'a': None, 'b': None, 'c': None,...
# 3C95A  {'default': [{'a': None, 'b': None, 'c': None,...
# 3C95F  {'default': [{'a': None, 'b': None, 'c': None,...
# 3C96   {'default': [{'a': None, 'b': None, 'c': None,...
# 3C97   {'default': [{'a': None, 'b': None, 'c': None,...

# %%
print("Nr of material families: " + str(len(df_materials['family'].unique())))
print("Family unique values: " + str(df_materials['family'].unique()))
# Out:
# Nr of material families: 36
# Family unique values: ['3C' '3F' '4F' 'NiZn' '75-Series' 'MnZn' 'A' 'DMR' 'Edge' 'FS' 'GX' 'HF'
#  'High DC Bias Edge' 'High DC Bias XFlux' 'High Flux' 'JNP' 'Kool Mµ'
#  'Kool Mµ Hƒ' 'Kool Mµ MAX' 'Kool Mµ Ultra' 'MP' 'MPP' 'MS' 'Mix' 'N' 'OC'
#  'OD' 'OE' 'OP' 'PC' 'SH' 'SM' 'SMP' 'TP' 'XFlux' 'XFlux Ultra']

# %%
# plot the cores histogram based on family column values in df_cores
fig, ax = plt.subplots(figsize=(15, 10))
ax.bar(df_materials['family'].value_counts().index, df_materials['family'].value_counts().values)
ax.set_xlabel('Core Family')
ax.set_ylabel('Number of Cores')
ax.set_title('Histogram of Core Families')
ax.xaxis.set_tick_params(rotation=45)
ax.grid(True)
plt.show()
